# %%
import numpy as np
import pandas as pd
import os 
import matplotlib.pyplot as plt
import math

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL'
os.chdir(BASE_DIR)

# %% [markdown]
# ### **dataset A**

# %%
print('current directory: ', os.getcwd())
data_path = os.path.join(BASE_DIR,)
# Out:
# current directory:  /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm.zip" -d "/content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm"
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm.zip
# replace /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S154W1.eea? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S154W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S155W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s157w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s158w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S163W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S164W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S165W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S167W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S169W.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s170w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s173w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S174W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s176w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S177W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s178w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S179W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S182W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S196W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S10W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s12w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S18W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s20w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S26W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s27w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S31W.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S42W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s43w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S47W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S50W.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s53w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S55W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S59LW.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S60W.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S72W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S78W.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S85W1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s94w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/s152w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm/S153W1.eea

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch.zip" -d "/content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch"
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch.zip
# replace /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/510-1W.eea? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/510-1W.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/515w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/517w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/540w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/548w.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/573w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/575w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/585w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/586w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/642w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/683w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/719w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/r229w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/r416w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/s083w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/S084-1W.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/s351w.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/s425w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/022w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/32w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/33w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/088w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/103w.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/113w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/155w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/156w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/192w.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/219w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/221w.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/249w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/276w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/307w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/312w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/314w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/342mw1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/382w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/387-02w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/387-03w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/401w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/423w.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/429w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/454-1W.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/485w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/508w1.eea
#   inflating: /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/sch/509w1.eea

# %%
norm_path = os.path.join(data_path, 'norm')
sch_path = os.path.join(data_path, 'sch')

# %%
norm_path
# Out:
# '/content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/norm'

# %% [markdown]
# **read the data from files**

# %%
def read_data(subjects_path):
  subjects_list = []
  for filename in os.listdir(subjects_path):
    with open(os.path.join(subjects_path, filename), 'r') as f:
      lines = f.readlines()
      subjects_list.append(lines)
  return subjects_list


def convert_to_numbers(sub_list):
  new_list = []
  for sub in sub_list:
    new_list.append([float(value) for value in sub])
  return new_list



healthy_subjects_str = read_data(norm_path)
sch_subjects_str  = read_data(sch_path)
healthy_subjects = convert_to_numbers(healthy_subjects_str)
sch_subjects = convert_to_numbers(sch_subjects_str)

# %% [markdown]
# **divide into 16 channels**

# %%
def segment_list(lst, segments=16):
  arr = np.array(lst)
  return np.array_split(np.array(arr), segments)

def divide_to_channels(subjects_list, segments=16):
  return [segment_list(subject, segments) for subject in subjects_list]

# %%
# (no. cases, 16, 7680)
sz_channels = divide_to_channels(sch_subjects)
hc_channels = divide_to_channels(healthy_subjects)

recording_len = sz_channels[0][0].shape[0]
print('length of each channel: ',recording_len)

len(sz_channels), len(hc_channels)
# Out:
# length of each channel:  7680
# (45, 39)

# %%
from matplotlib import gridspec

colors = ['black', 'darkorange', 'blue', 'red', 
          'cyan', 'limegreen', 'dodgerblue', 'violet', 
          'slateblue', 'pink', 'peru', 'navy', 
          'gold', 'black', 'green', 'royalblue', 'yellow']

def plot_subject_channels(data, subject_index=0, n_channels=16):
  #plt.style.use('seaborn-pastel')
  fig = plt.figure(figsize=(15, 20), dpi=80)
  gs = gridspec.GridSpec(n_channels, 1) 

  for i in range(0, n_channels):
    ax = plt.subplot(gs[i])
    ax.spines["top"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    line, = ax.plot(data[subject_index][i], color=colors[i])
    ax.set_yticklabels([])
    ax.set_ylabel(f'CH {i + 1}')
    plt.xlim([0, recording_len])

  # remove vertical gap between subplots
  plt.subplots_adjust(hspace=.0)
  plt.show()

# %%
print("16 channel plot of one  schizophernic subject")
plot_subject_channels(sz_channels)
# Out:
# 16 channel plot of one  schizophernic subject

# %%
print("16 channel plot of one healthy subject")
plot_subject_channels(hc_channels)
# Out:
# 16 channel plot of one healthy subject

# %% [markdown]
# total length of the recording is **1 minute** (7680 samples / 128 Hz sample rate) <br>
#
# dividing each recording into 5 second segments **(128 x 5 x 16 channels)**

# %%
freq = 128
total_time = recording_len // freq
print(f'the recording is {total_time} seconds long and has total {recording_len} values')
# Out:
# the recording is 60 seconds long and has total 7680 values

# %%
def divide_time_segments(subject_list, time_window=5):
    n_segments = total_time // time_window
    return [np.split(channel, n_segments) for channel in subject_list]


def create_spectrogram_data(subject_list):
    new_subject_list = []
    for subject in subject_list:
        specs = []
        segment_channels = divide_time_segments(subject)
        array_of_arrays = np.array([np.array(channel) for channel in segment_channels])
        for i in range(0, array_of_arrays.shape[1]):
            spec_data = np.squeeze(array_of_arrays[:, i, :].reshape((1, -1)))
            specs.append(spec_data)
        new_subject_list.append(specs)
    return new_subject_list


hc_spectrogram_data = create_spectrogram_data(hc_channels)
sz_spectrogram_data = create_spectrogram_data(sz_channels)

# %%
def plot_spectrogram(data):
  plt.specgram(data, Fs=128, cmap="cool")
  plt.axis('off')
  plt.show()

print('spectrogram of a healthy subject: \n')
plot_spectrogram(hc_spectrogram_data[1][0])

print('spectrogram of a schizophernia subject: \n')
plot_spectrogram(sz_spectrogram_data[1][0])
# Out:
# spectrogram of a healthy subject:
# spectrogram of a schizophernia subject:
