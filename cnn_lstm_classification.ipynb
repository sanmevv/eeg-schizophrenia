# %%
import tensorflow as tf
from tensorflow import keras
import pickle
import numpy as np
import cv2
import glob
import pathlib
import PIL, PIL.Image
import os
import math
import random
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import (Conv2D, MaxPooling2D, Flatten, Activation, Dropout, Dense, TimeDistributed, LSTM, ConvLSTM2D, MaxPooling3D)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dir = '/content/drive/MyDrive/Colab Notebooks'
data_dir = os.path.join(base_dir, 'EEG_SHCEEEZ-DL', 'out')
a_dataset = pathlib.Path(os.path.join(data_dir, 'A'))

# %%
image_count = len(list(a_dataset.glob('*/*.png')))
print('number of total images:', image_count, '\n\n')
# Out:
# number of total images: 720

# %%
def load_images(image_dims, data_dir):
  dir = os.listdir(data_dir)
  image_directory = [os.path.join(data_dir, image) for image in dir]
  images = []
  for i, image_path in enumerate(image_directory):
    image = tf.keras.preprocessing.image.load_img(image_path, target_size=image_dims)
    input_arr = (tf.keras.preprocessing.image.img_to_array(image))/255
    images.append(input_arr)
  return images

# ------------------------------------------------------
def list_segments(lst, segments):
  arr = np.array(lst)
  return np.array_split(np.array(arr), segments)

# %%
norm_images = load_images(image_dims=(224, 224), data_dir=os.path.join(a_dataset, 'norm')) 
sch_images = load_images(image_dims=(224, 224), data_dir=os.path.join(a_dataset, 'sch')) 
norm_cases = list_segments(norm_images, (len(norm_images)//12))
sch_cases = list_segments(sch_images, (len(sch_images)//12))

# %%
# ----------------------------------------------
def log_data_shapes(sch, norm):
  return {
 'sch': (len(sch), len(sch[0]), sch[0][0].shape), 
 'norm': (len(norm), len(norm[0]), norm[0][0].shape)}

log_data_shapes(sch_cases, norm_cases)
# Out:
# {'sch': (31, 12, (224, 224, 3)), 'norm': (29, 12, (224, 224, 3))}

# %%
def attach_labels(dataset, label):
  return [[sample, label] for sample in dataset]

dataset = []
dataset.extend(attach_labels(sch_cases, 0))
dataset.extend(attach_labels(norm_cases, 1))

# %%
def log_shape(dataset):
  print((len(dataset), len(dataset[0]), len(dataset[0][0]), (len(dataset[0][0][0]), len(dataset[0][0][0][0]), len(dataset[0][0][0][0][0]))))

# %%
def split_train_test(dataset, ratio=0.8, seed=123):
  train_len = math.floor(len(dataset) * ratio)
  random.seed(seed)
  random.shuffle(dataset)
  return dataset[:train_len], dataset[train_len:]

def split_data_label(dataset):
  X = []
  y = []
  for sample, label in dataset:
    X.append(sample)
    y.append(label)
  return np.array(X), np.array(y)


train_data, test_data = split_train_test(dataset)
print(len(train_data), len(test_data))
X_train, y_train = split_data_label(train_data)
X_test, y_test = split_data_label(test_data)
# Out:
# 48 12

# %%
log_shape(train_data)
log_shape(test_data)
print(len(X_train), len(X_train[0]), (len(X_train[0][0]), len(X_train[0][0][0]), len(X_train[0][0][0][0])))
# Out:
# (48, 2, 12, (224, 224, 3))
# (12, 2, 12, (224, 224, 3))
# 48 12 (224, 224, 3)

# %%
models_path = os.path.join(base_dir, 'EEG_SHCEEEZ-DL', 'models')

checkpoint = keras.callbacks.ModelCheckpoint(
    os.path.join(models_path, 'cnn_lstm_model.h5'),
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ####**CNN classification with a LSTM model**

# %%
model = Sequential()
       
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu'), input_shape = (12, 224, 224, 3)))
model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2)))) 
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))
model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same',activation = 'relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))                
model.add(TimeDistributed(Flatten()))
                                  
model.add(LSTM(64))
model.add(Dense(512, activation = "relu"))               
model.add(Dense(2, activation = "softmax"))

model.summary()

optimizer = keras.optimizers.Adam(learning_rate=0.00009)
model.compile(loss = 'sparse_categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])

model_history = model.fit(X_train, y_train, epochs=60, batch_size=8 ,validation_split=0.2, callbacks = [checkpoint])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 12, 224, 224, 32)  896
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 12, 112, 112, 32)  0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 12, 112, 112, 64)  18496
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 12, 56, 56, 64)   0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 12, 56, 56, 128)  73856
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 12, 28, 28, 128)  0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 12, 100352)       0
#  tributed)
#
#  lstm (LSTM)                 (None, 64)                25706752
#
#  dense (Dense)               (None, 512)               33280
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 25,834,306
# Trainable params: 25,834,306
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 5/5 [==============================] - ETA: 0s - loss: 0.7598 - accuracy: 0.4474
# Epoch 1: val_loss improved from inf to 0.69999, saving model to /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/models/cnn_lstm_model.h5
# 5/5 [==============================] - 22s 1s/step - loss: 0.7598 - accuracy: 0.4474 - val_loss: 0.7000 - val_accuracy: 0.4000
# Epoch 2/60
# 5/5 [==============================] - ETA: 0s - loss: 0.7044 - accuracy: 0.3947
# Epoch 2: val_loss improved from 0.69999 to 0.68454, saving model to /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/models/cnn_lstm_model.h5
# 5/5 [==============================] - 3s 599ms/step - loss: 0.7044 - accuracy: 0.3947 - val_loss: 0.6845 - val_accuracy: 0.6000
# Epoch 3/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5263
# Epoch 3: val_loss did not improve from 0.68454
# 5/5 [==============================] - 1s 209ms/step - loss: 0.6937 - accuracy: 0.5263 - val_loss: 0.6966 - val_accuracy: 0.4000
# Epoch 4/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6947 - accuracy: 0.5000
# Epoch 4: val_loss did not improve from 0.68454
# 5/5 [==============================] - 1s 227ms/step - loss: 0.6947 - accuracy: 0.5000 - val_loss: 0.7012 - val_accuracy: 0.4000
# Epoch 5/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6908 - accuracy: 0.5000
# Epoch 5: val_loss did not improve from 0.68454
# 5/5 [==============================] - 1s 228ms/step - loss: 0.6908 - accuracy: 0.5000 - val_loss: 0.6967 - val_accuracy: 0.4000
# Epoch 6/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6879 - accuracy: 0.5000
# Epoch 6: val_loss did not improve from 0.68454
# 5/5 [==============================] - 1s 236ms/step - loss: 0.6879 - accuracy: 0.5000 - val_loss: 0.6938 - val_accuracy: 0.4000
# Epoch 7/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6850 - accuracy: 0.7368
# Epoch 7: val_loss did not improve from 0.68454
# 5/5 [==============================] - 1s 215ms/step - loss: 0.6850 - accuracy: 0.7368 - val_loss: 0.6909 - val_accuracy: 0.6000
# Epoch 8/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6811 - accuracy: 0.7368
# Epoch 8: val_loss did not improve from 0.68454
# 5/5 [==============================] - 1s 219ms/step - loss: 0.6811 - accuracy: 0.7368 - val_loss: 0.6891 - val_accuracy: 0.6000
# Epoch 9/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6724 - accuracy: 0.7632
# Epoch 9: val_loss did not improve from 0.68454
# 5/5 [==============================] - 1s 230ms/step - loss: 0.6724 - accuracy: 0.7632 - val_loss: 0.6884 - val_accuracy: 0.6000
# Epoch 10/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6569 - accuracy: 0.7368
# Epoch 10: val_loss improved from 0.68454 to 0.68398, saving model to /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/models/cnn_lstm_model.h5
# 5/5 [==============================] - 2s 531ms/step - loss: 0.6569 - accuracy: 0.7368 - val_loss: 0.6840 - val_accuracy: 0.6000
# Epoch 11/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.7632
# Epoch 11: val_loss did not improve from 0.68398
# 5/5 [==============================] - 1s 220ms/step - loss: 0.6341 - accuracy: 0.7632 - val_loss: 0.6936 - val_accuracy: 0.7000
# Epoch 12/60
# 5/5 [==============================] - ETA: 0s - loss: 0.5673 - accuracy: 0.8158
# Epoch 12: val_loss improved from 0.68398 to 0.67260, saving model to /content/drive/MyDrive/Colab Notebooks/EEG_SHCEEEZ-DL/models/cnn_lstm_model.h5
# 5/5 [==============================] - 2s 518ms/step - loss: 0.5673 - accuracy: 0.8158 - val_loss: 0.6726 - val_accuracy: 0.6000
# Epoch 13/60
# 5/5 [==============================] - ETA: 0s - loss: 0.5542 - accuracy: 0.7895
# Epoch 13: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 211ms/step - loss: 0.5542 - accuracy: 0.7895 - val_loss: 0.7922 - val_accuracy: 0.4000
# Epoch 14/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6083 - accuracy: 0.6316
# Epoch 14: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 224ms/step - loss: 0.6083 - accuracy: 0.6316 - val_loss: 0.6991 - val_accuracy: 0.5000
# Epoch 15/60
# 5/5 [==============================] - ETA: 0s - loss: 0.5490 - accuracy: 0.8421
# Epoch 15: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 227ms/step - loss: 0.5490 - accuracy: 0.8421 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 16/60
# 5/5 [==============================] - ETA: 0s - loss: 0.4819 - accuracy: 0.8684
# Epoch 16: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 234ms/step - loss: 0.4819 - accuracy: 0.8684 - val_loss: 0.7364 - val_accuracy: 0.5000
# Epoch 17/60
# 5/5 [==============================] - ETA: 0s - loss: 0.4379 - accuracy: 0.8158
# Epoch 17: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 222ms/step - loss: 0.4379 - accuracy: 0.8158 - val_loss: 0.7608 - val_accuracy: 0.6000
# Epoch 18/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3837 - accuracy: 0.8947
# Epoch 18: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 227ms/step - loss: 0.3837 - accuracy: 0.8947 - val_loss: 0.9112 - val_accuracy: 0.3000
# Epoch 19/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8684
# Epoch 19: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 218ms/step - loss: 0.3705 - accuracy: 0.8684 - val_loss: 0.8372 - val_accuracy: 0.6000
# Epoch 20/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3344 - accuracy: 0.8947
# Epoch 20: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 220ms/step - loss: 0.3344 - accuracy: 0.8947 - val_loss: 1.1206 - val_accuracy: 0.4000
# Epoch 21/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8158
# Epoch 21: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 224ms/step - loss: 0.3464 - accuracy: 0.8158 - val_loss: 0.9473 - val_accuracy: 0.6000
# Epoch 22/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3749 - accuracy: 0.8421
# Epoch 22: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 223ms/step - loss: 0.3749 - accuracy: 0.8421 - val_loss: 0.9059 - val_accuracy: 0.4000
# Epoch 23/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3840 - accuracy: 0.8684
# Epoch 23: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 230ms/step - loss: 0.3840 - accuracy: 0.8684 - val_loss: 0.7576 - val_accuracy: 0.7000
# Epoch 24/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3966 - accuracy: 0.8684
# Epoch 24: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 222ms/step - loss: 0.3966 - accuracy: 0.8684 - val_loss: 0.9068 - val_accuracy: 0.5000
# Epoch 25/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.8421
# Epoch 25: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 220ms/step - loss: 0.3127 - accuracy: 0.8421 - val_loss: 1.1170 - val_accuracy: 0.5000
# Epoch 26/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.9211
# Epoch 26: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 211ms/step - loss: 0.2714 - accuracy: 0.9211 - val_loss: 1.0248 - val_accuracy: 0.6000
# Epoch 27/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.8947
# Epoch 27: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 220ms/step - loss: 0.3355 - accuracy: 0.8947 - val_loss: 1.0151 - val_accuracy: 0.4000
# Epoch 28/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2639 - accuracy: 0.8684
# Epoch 28: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 242ms/step - loss: 0.2639 - accuracy: 0.8684 - val_loss: 1.0608 - val_accuracy: 0.5000
# Epoch 29/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9211
# Epoch 29: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 242ms/step - loss: 0.2469 - accuracy: 0.9211 - val_loss: 1.1755 - val_accuracy: 0.5000
# Epoch 30/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.8947
# Epoch 30: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 221ms/step - loss: 0.2173 - accuracy: 0.8947 - val_loss: 1.2115 - val_accuracy: 0.2000
# Epoch 31/60
# 5/5 [==============================] - ETA: 0s - loss: 0.5080 - accuracy: 0.7105
# Epoch 31: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 211ms/step - loss: 0.5080 - accuracy: 0.7105 - val_loss: 0.8989 - val_accuracy: 0.3000
# Epoch 32/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3933 - accuracy: 0.8158
# Epoch 32: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 223ms/step - loss: 0.3933 - accuracy: 0.8158 - val_loss: 0.9044 - val_accuracy: 0.6000
# Epoch 33/60
# 5/5 [==============================] - ETA: 0s - loss: 0.3194 - accuracy: 0.8947
# Epoch 33: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 220ms/step - loss: 0.3194 - accuracy: 0.8947 - val_loss: 0.9608 - val_accuracy: 0.5000
# Epoch 34/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2721 - accuracy: 0.9474
# Epoch 34: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 221ms/step - loss: 0.2721 - accuracy: 0.9474 - val_loss: 1.0054 - val_accuracy: 0.6000
# Epoch 35/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2328 - accuracy: 0.9474
# Epoch 35: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 212ms/step - loss: 0.2328 - accuracy: 0.9474 - val_loss: 1.0868 - val_accuracy: 0.5000
# Epoch 36/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9474
# Epoch 36: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 222ms/step - loss: 0.1993 - accuracy: 0.9474 - val_loss: 1.1734 - val_accuracy: 0.4000
# Epoch 37/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1641 - accuracy: 0.9474
# Epoch 37: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 221ms/step - loss: 0.1641 - accuracy: 0.9474 - val_loss: 1.4359 - val_accuracy: 0.4000
# Epoch 38/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9211
# Epoch 38: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1755 - accuracy: 0.9211 - val_loss: 1.4100 - val_accuracy: 0.4000
# Epoch 39/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9474
# Epoch 39: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 237ms/step - loss: 0.1775 - accuracy: 0.9474 - val_loss: 1.2819 - val_accuracy: 0.5000
# Epoch 40/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9211
# Epoch 40: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 235ms/step - loss: 0.2036 - accuracy: 0.9211 - val_loss: 1.1919 - val_accuracy: 0.6000
# Epoch 41/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9211
# Epoch 41: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 233ms/step - loss: 0.2106 - accuracy: 0.9211 - val_loss: 1.2295 - val_accuracy: 0.4000
# Epoch 42/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9474
# Epoch 42: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 214ms/step - loss: 0.1809 - accuracy: 0.9474 - val_loss: 1.1343 - val_accuracy: 0.6000
# Epoch 43/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9211
# Epoch 43: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 221ms/step - loss: 0.1946 - accuracy: 0.9211 - val_loss: 1.2354 - val_accuracy: 0.6000
# Epoch 44/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1552 - accuracy: 0.9474
# Epoch 44: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 211ms/step - loss: 0.1552 - accuracy: 0.9474 - val_loss: 1.3107 - val_accuracy: 0.4000
# Epoch 45/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9474
# Epoch 45: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1462 - accuracy: 0.9474 - val_loss: 1.2291 - val_accuracy: 0.5000
# Epoch 46/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9737
# Epoch 46: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1245 - accuracy: 0.9737 - val_loss: 1.2562 - val_accuracy: 0.7000
# Epoch 47/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9737
# Epoch 47: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1170 - accuracy: 0.9737 - val_loss: 1.4619 - val_accuracy: 0.4000
# Epoch 48/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9474
# Epoch 48: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 210ms/step - loss: 0.1105 - accuracy: 0.9474 - val_loss: 1.4983 - val_accuracy: 0.4000
# Epoch 49/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9737
# Epoch 49: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 222ms/step - loss: 0.1007 - accuracy: 0.9737 - val_loss: 1.4134 - val_accuracy: 0.6000
# Epoch 50/60
# 5/5 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9737
# Epoch 50: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0815 - accuracy: 0.9737 - val_loss: 1.5576 - val_accuracy: 0.4000
# Epoch 51/60
# 5/5 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 1.0000
# Epoch 51: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 1.8411 - val_accuracy: 0.4000
# Epoch 52/60
# 5/5 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 1.5467 - val_accuracy: 0.5000
# Epoch 53/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.9211
# Epoch 53: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 244ms/step - loss: 0.1602 - accuracy: 0.9211 - val_loss: 1.7212 - val_accuracy: 0.4000
# Epoch 54/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9474
# Epoch 54: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 230ms/step - loss: 0.1255 - accuracy: 0.9474 - val_loss: 1.5963 - val_accuracy: 0.6000
# Epoch 55/60
# 5/5 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9737
# Epoch 55: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0802 - accuracy: 0.9737 - val_loss: 1.6472 - val_accuracy: 0.5000
# Epoch 56/60
# 5/5 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 1.0000
# Epoch 56: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 1.7127 - val_accuracy: 0.4000
# Epoch 57/60
# 5/5 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 1.0000
# Epoch 57: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 1.7624 - val_accuracy: 0.5000
# Epoch 58/60
# 5/5 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 1.0000
# Epoch 58: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 1.8414 - val_accuracy: 0.5000
# Epoch 59/60
# 5/5 [==============================] - ETA: 0s - loss: 0.0867 - accuracy: 0.9474
# Epoch 59: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0867 - accuracy: 0.9474 - val_loss: 1.8907 - val_accuracy: 0.4000
# Epoch 60/60
# 5/5 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9211
# Epoch 60: val_loss did not improve from 0.67260
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1414 - accuracy: 0.9211 - val_loss: 1.5624 - val_accuracy: 0.6000

# %%
loss, acc = model.evaluate(X_test, y_test, batch_size= 4)
print(f"lstm model's accuracy: {round((acc * 100), 2)}%")
# Out:
# 3/3 [==============================] - 1s 34ms/step - loss: 0.7469 - accuracy: 0.7500
# model's accuracy: 75.0%

# %%
def predict(model):
  return np.argmax(model.predict([X_test]), axis=-1)

print(f'Predictions: {predict(model)},\nTrue label:  {y_test}')
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predictions: [1 1 1 1 0 0 1 0 1 0 0 1],
# True label:  [0 1 1 0 0 0 1 0 1 0 0 0]
